# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaroshan2007/Data-Analysis-Projects/blob/main/Mental_Health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sea
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("/content/drive/MyDrive/Mental Health Dataset.csv")

# %% [markdown]
# Data Cleaning

# %%
file.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days              1             No
# 1            Yes       Yes    1-14 days              1             No
# 2            Yes       Yes    1-14 days              1             No
# 3            Yes       Yes    1-14 days              1             No
# 4            Yes       Yes    1-14 days              1             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
file.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
file["Growing_Stress"].replace("Yes",1,inplace=True)
file["Growing_Stress"].replace("No",0,inplace=True)

# %%
file
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
file["Growing_Stress"].replace(1,"Yes",inplace=True)
file["Growing_Stress"].replace(0,"No",inplace=True)
# Out:
# <ipython-input-3-5d7137722597>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   file["Growing_Stress"].replace(1,"Yes",inplace=True)
# <ipython-input-3-5d7137722597>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
file
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
file.fillna("Data Not Present",inplace=True)

# %%
file.head()
# Out:
#          Timestamp  Gender        Country Occupation     self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate  Data Not Present
# 1  8/27/2014 11:31  Female  United States  Corporate  Data Not Present
# 2  8/27/2014 11:32  Female  United States  Corporate  Data Not Present
# 3  8/27/2014 11:37  Female  United States  Corporate                No
# 4  8/27/2014 11:43  Female  United States  Corporate                No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days              1             No
# 1            Yes       Yes    1-14 days              1             No
# 2            Yes       Yes    1-14 days              1             No
# 3            Yes       Yes    1-14 days              1             No
# 4            Yes       Yes    1-14 days              1             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# ...

# %%
file["Days_Indoors"]
# Out:
# 0          1-14 days
# 1          1-14 days
# 2          1-14 days
# 3          1-14 days
# 4          1-14 days
#              ...
# 292359    15-30 days
# 292360    15-30 days
# 292361    15-30 days
# 292362    15-30 days
# 292363    15-30 days
# Name: Days_Indoors, Length: 292364, dtype: object

# %%
file["Days_Indoors"].unique()
# Out:
# array(['1-14 days', 'Go out Every day', 'More than 2 months',
#        '15-30 days', '31-60 days'], dtype=object)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            292364 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Mood_Swings              292364 non-null  object
#  12  Coping_Struggles         292364 non-null  object
# ...

# %%
file.isnull().sum()
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
sea.countplot(data=file, y="Country",color='#ffdab9')
plt.title("COUNTRY VS COUNT")
plt.xlabel("GENDER")
plt.ylabel("")
plt.show()

# %%
sea.countplot(data=file, x="Gender",color='#ffdab9')
plt.title("GENDER")
#plt.xlabel("GENDER")
plt.ylabel("")
plt.show()

# %%
sea.countplot(data=file, x="Occupation",hue='Gender')
plt.title("OCCUPATION VS COUNT")
plt.xlabel("OCCUPATION")
plt.ylabel("")
plt.show()

# %%
file.filter(["Country","self_employed"]).value_counts()
# Out:
# Country                 self_employed
# United States           No               158608
# United Kingdom          No                43560
# Canada                  No                14694
# United States           Yes                9448
# United Kingdom          Yes                7064
# Australia               No                 5246
# Netherlands             No                 4724
# Ireland                 No                 3598
# Germany                 No                 3510
# Canada                  Yes                2862
# Sweden                  No                 2818
# India                   No                 2384
# New Zealand             No                 1994
# Ireland                 Yes                1950
# France                  No                 1950
# Brazil                  No                 1560
# Italy                   No                 1560
# Israel                  No                 1560
# South Africa            No                 1560
# ...

# %% [markdown]
# SELF EMPLOYMENT

# %%
sea.countplot(data=file,x='self_employed',hue='Occupation')
plt.title("SELF EMPLOYMENT")
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(40, 25))
sea.barplot(data=file, x="Country", y="self_employed",color='#00ff00')
plt.title("SELF EMPLOYMENT VS COUNTRY")
plt.xlabel("")
plt.ylabel("COUNTRIES")
plt.show()

# %%
sea.barplot(data=file, x="Gender", y="self_employed",color='#00ff00')
plt.title("SELF EMPLOYMENT VS GENDER")
plt.xlabel("GENDER")
plt.ylabel("SELF EMPLOYMENT")
plt.show()

# %%
sea.barplot(data=file,x='Growing_Stress',y='self_employed')
plt.show()

# %%
file["Occupation"].value_counts()
# Out:
# Occupation
# Housewife    66351
# Student      61794
# Corporate    61229
# Others       52841
# Business     50149
# Name: count, dtype: int64

# %%
file.filter(["Gender","Occupation"]).value_counts()
# Out:
# Gender  Occupation
# Male    Housewife     54735
#         Corporate     52275
#         Student       49815
#         Others        42435
#         Business      40590
# Female  Student       11979
#         Housewife     11616
#         Others        10406
#         Business       9559
#         Corporate      8954
# Name: count, dtype: int64

# %% [markdown]
# OCCUPATION

# %%
sea.displot(data=file,x='Occupation',hue='Country')
plt.show()

# %%
x = file["Gender"]
y = file["Occupation"]
plt.title("OCCUPATION VS GENDER")
plt.xlabel("GENDER")
plt.ylabel("OCCUPATION")
plt.stem(y,x,markerfmt='bo', basefmt='g-')
plt.show()

# %%
file['family_history'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
file.filter(["family_history","Gender"]).value_counts()
# Out:
# family_history  Gender
# No              Male      156000
# Yes             Male       83850
#                 Female     31682
# No              Female     20832
# Name: count, dtype: int64

# %% [markdown]
# FAMILY HISTORY

# %%
plt.figure(figsize=(10, 8))
x = file["family_history"]
y = file["Country"]
plt.scatter(x,y)
plt.title("COUNTRY VS FAMILY HISTORY (AVERAGE)")
plt.xlabel("FAMILY HISTORY")
plt.ylabel("COUNTRIES")
plt.show()

# %%
file["family_history"].replace("Yes",1)
file["family_history"].replace("No",0)
file["Gender"].replace("Male",2)
file["Gender"].replace("Female",3)
sea.displot(data=file, x="family_history", hue="Gender")
plt.title("FAMILY HISTORY")
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
file["Days_Indoors"].unique()
# Out:
# array(['1-14 days', 'Go out Every day', 'More than 2 months',
#        '15-30 days', '31-60 days'], dtype=object)

# %%
file["Days_Indoors"].value_counts()
# Out:
# Days_Indoors
# 1-14 days             63548
# 31-60 days            60705
# Go out Every day      58366
# More than 2 months    55916
# 15-30 days            53829
# Name: count, dtype: int64

# %% [markdown]
# Analysis

# %% [markdown]
# TREATMENT

# %%
plt.figure(figsize=(45, 30))
sea.barplot(data=file,x='Country',y='treatment',hue="Gender")
plt.title("COUNTRY VS NO OF PEOPLE TAKING TREATMENT FOR MENTAL HEALTH ISSUES",fontsize=20)
plt.xlabel("COUNTRY",fontsize=20)
plt.ylabel("TREATMENT",fontsize=20)
plt.show()

# %%
file["treatment"].replace("Yes",1)
file["treatment"].replace("No",0)
file["Gender"].replace("Male",2)
file["Gender"].replace("Female",3)
sea.displot(data=file, x="Gender", hue="treatment",stat='density')
plt.title("GENDER VS TREATMENT (OVERALL)")
plt.xlabel("GENDER")
plt.ylabel("TREATMENT")
plt.show()

# %%
file["treatment"].value_counts()
# Out:
# treatment
# Yes    147606
# No     144758
# Name: count, dtype: int64

# %%
sea.violinplot(data=file, x="treatment",color='#fdf5e6')
plt.title("PEOLPE UNDERGOING TREATMENT FOR MENTAL HEALTH ISSUES")
plt.xlabel("TREATMENT")
plt.show()

# %%
file["treatment"].value_counts()
# Out:
# treatment
# Yes    147606
# No     144758
# Name: count, dtype: int64

# %%
sea.boxplot(data=file, x="treatment", y="care_options",hue='Gender')
plt.title("TREATMENT VS CARE OPTIONS")
plt.xlabel("TREATMENT")
plt.ylabel("CARE OPTIONS")
plt.show()

# %%
file.filter(['Days_Indoors','Country']).value_counts()
# Out:
# Days_Indoors        Country
# 1-14 days           United States    37082
# 31-60 days          United States    35568
# Go out Every day    United States    34258
# More than 2 months  United States    32804
# 15-30 days          United States    31596
#                                      ...
#                     Philippines         71
#                     Moldova             71
#                     Mexico              71
#                     Thailand            71
#                     Nigeria             71
# Name: count, Length: 175, dtype: int64

# %% [markdown]
# PEOPLE STAYING INSIDE HOUSE

# %%
plt.figure(figsize=(25, 20))
sea.countplot(data=file,x='Days_Indoors',hue='Country')
plt.title("COUNTRY VS NO OF PEOPLE STAYING INSIDE HOUSE")
plt.xlabel("NO OF DAYS")
plt.ylabel("COUNT")
plt.show()

# %%
sea.lineplot(data=file, x="Gender", y="Days_Indoors")
plt.title("GENDER VS NO OF DAYS INSIDE HOUSE")
plt.xlabel("GENDER")
plt.ylabel("NO OF DAYS INDOOR")
plt.show()

# %% [markdown]
# GROWING STRESS

# %%
filtered_data = file[file["Country"] == "Russia"]
filtered_data.filter(['Country','Growing_Stress']).value_counts()
# Out:
# Country  Growing_Stress
# Russia   Maybe             274
#          Yes               256
#          No                250
# Name: count, dtype: int64

# %%
sea.displot(data=file, x="Growing_Stress", hue="Country",stat='density')
plt.title("COUNTRY VS GROWING STRESS")
plt.xlabel("GROWING STRESS")
plt.ylabel("")
plt.show()

# %%
x = file["Gender"]
y = file["Growing_Stress"]
plt.title("GENDER VS GROWING STRESS",color='blue')
plt.xlabel("GENDER",color='blue')
plt.ylabel("GROWING STRESS",color='blue')
plt.stackplot(x,y)
plt.show()

# %%
file.filter(['Occupation','Growing_Stress']).value_counts()
# Out:
# Occupation  Growing_Stress
# Housewife   Maybe             24167
# Corporate   Yes               23925
# Student     Maybe             23320
# Housewife   No                22584
# Student     Yes               21818
# Corporate   No                20255
# Housewife   Yes               19600
# Others      No                19015
# Business    Yes               18884
# Others      Maybe             18400
# Business    Maybe             17049
# Corporate   Maybe             17049
# Student     No                16656
# Others      Yes               15426
# Business    No                14216
# Name: count, dtype: int64

# %%
sea.barplot(data=file,x='Occupation',y='Growing_Stress',color='#ceff00')
plt.title("OCCUPATION VS GROWING STRESS")
plt.xlabel("OCCUPATION")
plt.ylabel("GROWING STRESS")
plt.show()

# %% [markdown]
# CHANGES IN HABIT

# %%
x = file['Gender']
y = file['Changes_Habits']
plt.stackplot(x,y)
plt.title("CHANGES IN HABIT vs GENDER",color='blue')
plt.xlabel("GENDER",color='blue')
plt.ylabel("CHANGES IN HABIT",color='blue')
plt.show()

# %%
sea.displot(data=file,x='treatment',hue='Changes_Habits')
plt.title("CHANGES IN HABITS")
plt.xlabel('TREATMENT')
plt.ylabel('COUNT')
plt.show()

# %%
m_file = file[file['Country']=='Germany']
m_file.filter(['Country','treatment']).value_counts()
# Out:
# Country  treatment
# Germany  No           2340
#          Yes          2340
# Name: count, dtype: int64

# %%
plt.figure(figsize=(45, 30))
sea.barplot(data=file,x='Country',y='Changes_Habits',color='#ffa07a')

#file['Country'] = file['Country'].astype('category')
#file['Country'] = file['Country'].cat.set_categories(sorted(file['Country'].unique(), reverse=True))

plt.title("COUNTRY VS CHANGES IN HABITS IN TREATMENT", fontsize='25')
plt.xlabel("COUNTRY",fontsize='25')
plt.ylabel("CHANGES IN HABITS IN TREATMENT",fontsize='25')
plt.show()

# %% [markdown]
# MENTAL HEALTH HISTORY

# %%
sea.violinplot(data=file,x='Mental_Health_History',y='Gender',color='#fdf5e6')
plt.title("MENTAL HEALTH HISTORY VS GENDER")
plt.xlabel("MENTAL HEALTH HISTORY")
plt.ylabel("GENDER")
plt.show()

# %%
sea.lineplot(data=file,x='Occupation',y='Mental_Health_History')
plt.title("MENTAL HEALTH HISTORY VS OCCUPATION")
plt.xlabel("OCCUPATION")
plt.ylabel("MENTAL HEALTH HISTORY")
plt.show()

# %%
plt.figure(figsize=(48, 15))
sea.lineplot(data=file,x='Country',y='Mental_Health_History')
#plt.xlabel()
plt.show()

# %% [markdown]
# Mood Swings

# %%
plt.figure(figsize=(30,15))
bars = sea.barplot(data=file,x='Gender',y='Mood_Swings',hue='Country')
plt.title('MOOD SWINGS VS GENDER',fontsize=20)
plt.xlabel('GENDER',fontsize=20)
plt.ylabel('MOOD SWINGS',fontsize=20)
plt.show()

# %%
sea.lineplot(data=file,x='Mood_Swings',y='treatment')
plt.title("MOOD SWINGS VS TREATMENT")
plt.xlabel("MOOD SWINGS")
plt.ylabel("TREATMENT")
plt.show()

# %%
X = 'Occupation'
Y = 'Mood_Swings'
sea.histplot(data=file,x=X,y=Y)
plt.title("OCCUPATION VS MOOD SWINGS")
plt.xlabel("OCCUAPTION")
plt.ylabel("MOOD SWINGS")
plt.show()

# %% [markdown]
# Copins Strugles

# %%
sea.lineplot(data=file,x='Gender',y='Coping_Struggles',color='red')
plt.title("GENDER VS COPING STRUGGLES",color='red')
plt.xlabel("GENDER",color='red')
plt.ylabel("COPING STRUGLES",color='red')
plt.show()

# %%
sea.barplot(data=file,x='Occupation',y='Coping_Struggles',hue='treatment')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sea.countplot(data=file, y="Country",hue='Coping_Struggles')
plt.title("COPING STRUGGLES",fontsize=15)
plt.xlabel("COUNT",fontsize=15)
plt.ylabel("COUNTRY",fontsize=15)
plt.show()

# %% [markdown]
# Work Intrest

# %%
sea.violinplot(data=file,x='Gender',y='Work_Interest',color='#ffff00')
plt.title("GENDER VS WORK INTREST")
plt.xlabel("GENDER")
plt.ylabel("WORK INTREST")
plt.show()

# %%
sea.barplot(data=file,x='Occupation',y='Work_Interest')
plt.title("WORK INTREST")
plt.xlabel("OCCUPATION")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(25, 20))
sea.countplot(data=file,x='Work_Interest',hue='Country')
plt.title("WORK INTREST",fontsize=15)
plt.xlabel("Work intrest",fontsize=15)
plt.ylabel("")
plt.show()

# %% [markdown]
# Social Weakness

# %%
sea.countplot(data=file,y='Gender',hue='Social_Weakness')
plt.title("SOCIAL WEAKNESS")
plt.xlabel("")
plt.ylabel("GENDER")
plt.show()

# %%
plt.figure(figsize=(30, 20))
sea.barplot(data=file,x='Occupation',y='Social_Weakness',hue='Country')
plt.title("OCCUPATION VS SOCIAL WEAKNESS",fontsize=20)
plt.xlabel("OCCUPATION",fontsize=20)
plt.ylabel("SOCIAL WEAKNESS",fontsize=20)
plt.show()

# %%
sea.barplot(data=file,x='Gender',y='Mental_Health_History',hue='treatment')
plt.title("GENDER VS MENTAL")
plt.show()
